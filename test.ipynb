# %%
import pandas as pd
print(pd.read_parquet('data/processed/typical_stats.parquet').head())
# Out:
#   location  hour  day_of_week       mean       std
# 0  Eastern     0            0  18.383242  3.851144
# 1  Eastern     0            1  18.616922  3.810498
# 2  Eastern     0            2  18.500385  3.883857
# 3  Eastern     0            3  18.563703  3.937432
# 4  Eastern     0            4  18.471105  3.849431

# %%
merged[(merged['location'] == 'Northern') & (merged['datetime'] == '2024-03-15 14:00:00')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 merged[(merged['location'] == 'Northern') & (merged['datetime'] == '2024-03-15 14:00:00')]
#
# NameError: name 'merged' is not defined
